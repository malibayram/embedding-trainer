# %%
from datasets import load_dataset

splits = ['final_tr_en', 'initial_tr_en', 'multilingual_batch']
datasets = {}
for split in splits:
    ds = load_dataset("alibayram/wikiset-multilingual", split)
    
    datasets[split] = ds
# Out:
# Downloading data:   0%|          | 0.00/18.0M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/9900 [00:00<?, ? examples/s]
# Downloading data:   0%|          | 0.00/18.0M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/9900 [00:00<?, ? examples/s]
# Downloading data:   0%|          | 0.00/98.2M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/56013 [00:00<?, ? examples/s]

# %%
from datasets import concatenate_datasets, DatasetDict

# assume your object is called `data`
# data = {...}  # the dict you showed

# extract train splits
train_datasets = [
    datasets["final_tr_en"]["train"],
    datasets["initial_tr_en"]["train"],
    datasets["multilingual_batch"]["train"],
]

# concatenate
combined_train = concatenate_datasets(train_datasets)

# wrap back into a DatasetDict
combined_dataset = DatasetDict({
    "train": combined_train
})

print(combined_dataset)
print("Total rows:", combined_dataset["train"].num_rows)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'url', 'title', 'text', 'lang'],
#         num_rows: 75813
#     })
# })
# Total rows: 75813

# %%
combined_train.push_to_hub("alibayram/wikiset")
# Out:
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/76 [00:00<?, ?ba/s]
# Uploading files as a binary IO buffer is not supported by Xet Storage. Falling back to HTTP upload.
# CommitInfo(commit_url='https://huggingface.co/datasets/alibayram/wikiset/commit/35c1ddc95744ccecef7dabeaaa4afa5167b5fed1', commit_message='Upload dataset', commit_description='', oid='35c1ddc95744ccecef7dabeaaa4afa5167b5fed1', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/alibayram/wikiset', endpoint='https://huggingface.co', repo_type='dataset', repo_id='alibayram/wikiset'), pr_revision=None, pr_num=None)

# %%
import ollama

response = ollama.embed(
    model='embeddinggemma',
    input=['The sky is blue because of Rayleigh scattering',"second text", "third text"],
)
print(response.embeddings)
# Out:
# [[-0.12277636, 0.0067556705, 0.0706596, 0.017811112, -0.015437452, 0.06627547, -0.007231198, 0.0061991173, 0.016938826, -0.009035891, -0.024286328, -0.036075637, 0.022906901, -0.03699966, 0.0426454, -0.057196263, 0.0453099, -0.042257633, 0.025363624, -0.06490879, -0.055416487, 0.07552626, 0.018485965, 0.0341167, 0.008598598, 0.045469683, -0.036071733, 0.051475044, -0.044114344, 0.007752617, -0.016141757, -0.005571793, 0.021338025, -0.025082525, 0.011389929, 0.06134824, -0.035977688, -0.02841617, 0.018774992, -0.053648267, -0.047720704, 0.0681137, -0.055949636, 0.031540073, 0.033536006, -0.012623063, -0.045866244, -0.06385417, 0.019944167, 0.073920645, 0.00075356115, -0.04305657, -0.07303683, 0.0010730012, -0.026756264, -0.053941578, -0.0065588085, 0.043575305, -0.021882012, 0.06861877, -0.025125068, -0.023960203, -0.024309626, -0.035290804, 0.080569364, -0.015892742, -0.0029112636, -0.00019201972, 0.057118148, 0.17238864, 0.0129292635, 0.014009113, -0.04611526, -0.013915334, 0.12372742, -0.046259966, -0.054960318, -0.0010489788, -0.035983644, 0.03775994, 0.022148484, 0.030112563, 0.0046072914, -0.023535447, 0.10388414, -0.015746426, -0.044580333, 0.00996909, -0.024934681, -0.04107081, 0.018032545, -0.021545762, -0.017067594, -0.05131222, 0.06725414, 0.022724476, 0.026779715, -0.016010959, -0.07685536, 0.00082286424, 0.04596584, 0.034598015, 0.008616237, 0.13725378, 0.04508564, 0.00413114, 0.002194745, -0.008822507, -0.002304142, 0.029445205, -0.031849872, -0.0056148553, -0.022610145, 0.032237086, -0.024855824, 0.009314792, -0.068734206, -0.02222415, -0.01690432, 0.014629758, -0.030148419, 0.0658541, 0.05754888, -0.018237954, 0.010000697, 0.03705107, 0.0014024223, 0.05199899, -0.023462666, -0.019213539, -0.0083508175, 0.037195813, 0.026048051, 0.0085138725, -0.012617614, 0.05057847, -0.0029323336, 0.075061396, 0.062031295, 0.024281092, 0.009529072, -0.04160918, -0.044585016, -0.0075620892, 0.025400095, -0.028226767, 0.0021786003, -0.018380195, -0.0385064, 0.0053681866, 0.04462294, -0.060501985, 0.039523665, 0.018666668, -0.008994884, 0.0029253599, 0.0073076095, 0.009165074, -0.017922804, -0.015765494, -0.025417263, -0.0069139353, 0.041807767, 0.06350741, 0.027120274, 0.03331823, -0.0019571267, 0.034335196, -0.029316362, -0.010805077, 0.043215238, -0.07840981, 0.005624504, 0.005366052, 0.00040880073, -0.039901875, 0.017440489, -0.026454085, 0.0448888, 0.036559056, -0.04251356, 0.039014675, 0.008026638, -0.061529823, -0.054906856, 0.034593757, 0.03325308, 0.06295847, -0.0204862, -0.025290793, -0.01267306, -0.10887874, -0.09908303, -0.06401674, 0.008834858, -0.0015204778, 0.067851946, -0.024003504, 0.0147553645, 0.032057784, 0.0037991682, -0.05544833, -0.0057319463, 0.003928521, -0.024733583, -0.010898778, 0.039366767, 0.001917404, -0.017089175, -0.027391136, 0.017932324, 0.069664836, 0.01572021, -0.006278365, -0.0063805976, 0.025205944, -0.029974608, -0.0093274955, -0.010745128, -0.013902149, 0.027655652, 0.042968843, 0.028136434, 0.005610858, -0.04045477, -0.04989631, 0.00021637673, -0.00511013, -0.003579391, -0.028057802, -0.034789737, 0.017106552, 0.010533569, -0.041818157, -0.060665756, 0.0059546186, -0.049940486, 0.02363455, 0.013026236, 0.044339065, -0.030811513, -0.06374399, 0.07259237, 0.0069943555, -0.0487961, 0.04457607, 0.033044744, 0.009761725, -0.04704898, -0.025790108, 0.060666025, -0.005292687, -0.00063060166, -0.041408297, -0.025696903, 0.010879487, 0.036489874, 0.03914364, 0.09140718, -0.03846479, 0.0192758, -0.045313135, 0.04690637, 0.02020171, 0.03494247, -0.0445746, 0.060082205, -0.01727339, -0.009556713, -0.028205054, -0.024995292, 0.03678875, -0.03867103, 0.0055031343, 0.016071334, 0.031631723, 0.029035732, 0.034053512, -0.019132944, 0.002951038, -0.0013736461, -0.01950378, 0.039906207, 0.03635152, -0.05590671, 0.010491802, -0.03516087, 0.014435994, -0.0075650057, -0.056293968, 0.013098417, 0.01823146, -0.0016621265, -0.013583119, 0.038606457, -0.034977574, 0.02028294, -0.052913863, -0.06119324, -0.025741104 ...

# %%
len(response.embeddings)
# Out:
# 2

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("google/gemma-3-1b-it")

# %%
from transformers import AutoTokenizer

org_tokenizer = AutoTokenizer.from_pretrained("magibu-200m-base")
org_tokenizer.push_to_hub("alibayram/magibu-200m-tr")
# Out:
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# CommitInfo(commit_url='https://huggingface.co/alibayram/magibu-200m-tr/commit/48f037806ee48ec0ab2261fc7cde7e51e3b19078', commit_message='Upload tokenizer', commit_description='', oid='48f037806ee48ec0ab2261fc7cde7e51e3b19078', pr_url=None, repo_url=RepoUrl('https://huggingface.co/alibayram/magibu-200m-tr', endpoint='https://huggingface.co', repo_type='model', repo_id='alibayram/magibu-200m-tr'), pr_revision=None, pr_num=None)

# %%
from sentence_transformers import SentenceTransformer

# embeddingmagibu = SentenceTransformer("alibayram/magibu-200m", revision="b2642210e2a06e1c744af60adb8c10051d3465d5") 0.6487
embeddingmagibu = SentenceTransformer("alibayram/magibu-200m", revision="63f250364fb6661d90f61420916539b5a68b4d95")
embeddingmagibu.save_pretrained("magibu-200m")
# Out:
# Loading weights:   0%|          | 0/314 [00:00<?, ?it/s]

# %%
embeddingmagibu.push_to_hub("alibayram/magibu-128k-200m")
# Out:
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# 'https://huggingface.co/alibayram/magibu-128k-200m/commit/84fa4ec89fd2fcb5e498c91376ff42ec5fe0366e'

# %%
import torch
from sentence_transformers import SentenceTransformer
from transformers import Gemma3TextModel, AutoTokenizer

embeddinggemma = SentenceTransformer("google/embeddinggemma-300m")
embeddinggemma.save_pretrained("magibu-200m-base")

model = Gemma3TextModel.from_pretrained("google/embeddinggemma-300m")

embeddings = model.embed_tokens.weight
print(f"Embeddings shape: {embeddings.shape}")

org_tokenizer = AutoTokenizer.from_pretrained("google/embeddinggemma-300m")
target_tokenizer = AutoTokenizer.from_pretrained("alibayram/magibu-128k-processor")
print(f"Tokenizer vocab size: {org_tokenizer.vocab_size}, {target_tokenizer.vocab_size}")
# Out:
# Loading weights:   0%|          | 0/314 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/314 [00:00<?, ?it/s]
# Embeddings shape: torch.Size([262144, 768])
# Tokenizer vocab size: 262144, 131072

# %%
errors = []
for i in range(target_tokenizer.vocab_size):
    if i not in token_id_map or not token_id_map[i]:
        errors.append(i)
        # Initialize with zeros for unmapped tokens
        continue

    source_ids = token_id_map[i]
    # MEAN token strategy: average the source token embeddings
    # remove <bos> if present
    if source_ids[0] == org_tokenizer.bos_token_id:
        source_ids = source_ids[1:]
    embeddings_to_average = embeddings[source_ids]
    new_embeddings[i] = embeddings_to_average.mean(dim=0)

    if (i + 1) % 10000 == 0:
        print(f"Mapped {i + 1}/{target_tokenizer.vocab_size} embeddings", flush=True)

model.resize_token_embeddings(embeddings.shape[1])
print(model)

# %%
new_embeddings = torch.zeros(target_tokenizer.vocab_size, embeddings.shape[1], dtype=embeddings.dtype)
print(f"Embeddings {new_embeddings.shape}")
# Out:
# Embeddings torch.Size([131072, 768])

# %%
source_vocab = org_tokenizer.get_vocab()
target_vocab = target_tokenizer.get_vocab()

token_id_map = {}
direct_matches = 0
tokenized_matches = 0

for token_str, target_id in target_vocab.items():
    if token_str in source_vocab:
        # Direct match - use source token ID directly
        token_id_map[target_id] = [source_vocab[token_str]]
        direct_matches += 1
    else:
        # Token not in source vocab - need to tokenize
        encoded = org_tokenizer.encode(token_str, add_special_tokens=False)
        if encoded:
            token_id_map[target_id] = encoded
            tokenized_matches += 1

print(f"Token id map {len(token_id_map)}")
# Out:
# Token id map 131073

# %%
embeddings.shape
# Out:
# torch.Size([262144, 768])

# %%
from sentence_transformers import SentenceTransformer

embeddinggemma = SentenceTransformer("google/embeddinggemma-300m")
embeddinggemma
# Out:
# Loading weights:   0%|          | 0/314 [00:00<?, ?it/s]
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 2048, 'do_lower_case': False, 'architecture': 'Gemma3TextModel'})
#   (1): Pooling({'word_embedding_dimension': 768, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   (2): Dense({'in_features': 768, 'out_features': 3072, 'bias': False, 'activation_function': 'torch.nn.modules.linear.Identity'})
#   (3): Dense({'in_features': 3072, 'out_features': 768, 'bias': False, 'activation_function': 'torch.nn.modules.linear.Identity'})
#   (4): Normalize()
# )

# %%
embeddinggemma.save("embeddinggemma-300m")

# %%
from transformers import Gemma3TextModel

model = Gemma3TextModel.from_pretrained("embeddinggemma-300m")
model
# Out:
# Loading weights:   0%|          | 0/314 [00:00<?, ?it/s]
# Gemma3TextModel(
#   (embed_tokens): Gemma3TextScaledWordEmbedding(262144, 768, padding_idx=0)
#   (layers): ModuleList(
#     (0-23): 24 x Gemma3DecoderLayer(
#       (self_attn): Gemma3Attention(
#         (q_proj): Linear(in_features=768, out_features=768, bias=False)
#         (k_proj): Linear(in_features=768, out_features=256, bias=False)
#         (v_proj): Linear(in_features=768, out_features=256, bias=False)
#         (o_proj): Linear(in_features=768, out_features=768, bias=False)
#         (q_norm): Gemma3RMSNorm((256,), eps=1e-06)
#         (k_norm): Gemma3RMSNorm((256,), eps=1e-06)
#       )
#       (mlp): Gemma3MLP(
#         (gate_proj): Linear(in_features=768, out_features=1152, bias=False)
#         (up_proj): Linear(in_features=768, out_features=1152, bias=False)
#         (down_proj): Linear(in_features=1152, out_features=768, bias=False)
#         (act_fn): GELUTanh()
#       )
#       (input_layernorm): Gemma3RMSNorm((768,), eps=1e-06)
#       (post_attention_layernorm): Gemma3RMSNorm((768,), eps=1e-06)
#       (pre_feedforward_layernorm): Gemma3RMSNorm((768,), eps=1e-06)
#       (post_feedforward_layernorm): Gemma3RMSNorm((768,), eps=1e-06)
#     )
#   )
#   (norm): Gemma3RMSNorm((768,), eps=1e-06)
#   (rotary_emb): Gemma3RotaryEmbedding()
# )

# %%
embeddings = model.model.embed_tokens.weight
print(f"Embeddings shape: {embeddings.shape}")
# Out:
# Embeddings shape: torch.Size([262144, 768])

# %%
from sentence_transformers import SentenceTransformer

embeddingmagibu = SentenceTransformer(
    "alibayram/magibu-128k-200m-sft",
    revision="c90916b8e6fc57a808760c6262ac5d47721f9060",
)
embeddingmagibu
# Out:
# No sentence-transformers model found with name alibayram/magibu-128k-200m-sft. Creating a new one with mean pooling.
# Loading weights:   0%|          | 0/314 [00:00<?, ?it/s]
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 2048, 'do_lower_case': False, 'architecture': 'Gemma3TextModel'})
#   (1): Pooling({'word_embedding_dimension': 768, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
# )

# %%
temp = SentenceTransformer("alibayram/magibu-200m-multi")
temp.save_pretrained("magibu-128k-200m-multi")
# Out:
# Loading weights:   0%|          | 0/314 [00:00<?, ?it/s]

# %%
temp
# Out:
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 2048, 'do_lower_case': False, 'architecture': 'Gemma3TextModel'})
#   (1): Pooling({'word_embedding_dimension': 768, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   (2): Dense({'in_features': 768, 'out_features': 3072, 'bias': False, 'activation_function': 'torch.nn.modules.linear.Identity'})
#   (3): Dense({'in_features': 3072, 'out_features': 768, 'bias': False, 'activation_function': 'torch.nn.modules.linear.Identity'})
#   (4): Normalize()
# )

# %%
embeddingmagibu.save_pretrained("magibu-128k-200m-sft-mm")

# %%
from sentence_transformers import SentenceTransformer

embeddingmagibu_200m = SentenceTransformer("magibu-128k-200m-multi")
embeddingmagibu_200m
# Out:
# Loading weights:   0%|          | 0/314 [00:00<?, ?it/s]
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 8192, 'do_lower_case': False, 'architecture': 'Gemma3TextModel'})
#   (1): Pooling({'word_embedding_dimension': 768, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   (2): Dense({'in_features': 768, 'out_features': 3072, 'bias': False, 'activation_function': 'torch.nn.modules.linear.Identity'})
#   (3): Dense({'in_features': 3072, 'out_features': 768, 'bias': False, 'activation_function': 'torch.nn.modules.linear.Identity'})
#   (4): Normalize()
# )

# %%
embeddingmagibu_200m.push_to_hub("magibu/embeddingmagibu-200m", exist_ok=True)
# Out:
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# 'https://huggingface.co/magibu/embeddingmagibu-200m/commit/d8c037aa999bd9c009b8ba7a5370bcb7ebe111b4'

# %%
from transformers import AutoTokenizer

org_tokenizer = AutoTokenizer.from_pretrained("magibu-200m-base")
org_tokenizer.push_to_hub("alibayram/magibu-128k-processor")
# Out:
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# CommitInfo(commit_url='https://huggingface.co/alibayram/magibu-128k-processor/commit/030c5431123132a6c1fa27d08b3eb400a836a42a', commit_message='Upload tokenizer', commit_description='', oid='030c5431123132a6c1fa27d08b3eb400a836a42a', pr_url=None, repo_url=RepoUrl('https://huggingface.co/alibayram/magibu-128k-processor', endpoint='https://huggingface.co', repo_type='model', repo_id='alibayram/magibu-128k-processor'), pr_revision=None, pr_num=None)

# %%
from transformers import AutoTokenizer

org_tokenizer = AutoTokenizer.from_pretrained("embeddinggemma-300m")
target_tokenizer = AutoTokenizer.from_pretrained("alibayram/magibu-128k-processor", use_fast=True)
print(f"Tokenizer vocab size: {org_tokenizer.vocab_size}, {target_tokenizer.vocab_size}")
# Out:
# Tokenizer vocab size: 262144, 131072

# %%
source_vocab = org_tokenizer.get_vocab()
target_vocab = target_tokenizer.get_vocab()

token_id_map = {}
direct_matches = 0
tokenized_matches = 0

for token_str, target_id in target_vocab.items():
    if token_str in source_vocab:
        # Direct match - use source token ID directly
        token_id_map[target_id] = [source_vocab[token_str]]
        direct_matches += 1
    else:
        # Token not in source vocab - need to tokenize
        encoded = org_tokenizer.encode(token_str, add_special_tokens=False)
        if encoded:
            token_id_map[target_id] = encoded
            tokenized_matches += 1

# %%
import torch

new_embeddings = torch.zeros(target_tokenizer.vocab_size, embeddings.shape[1], dtype=embeddings.dtype)
errors = []
for i in range(target_tokenizer.vocab_size):
    if i not in token_id_map or not token_id_map[i]:
        errors.append(i)
        # Initialize with zeros for unmapped tokens
        continue
    
    source_ids = token_id_map[i]
    # MEAN token strategy: average the source token embeddings
    # remove <bos> if present
    if source_ids[0] == org_tokenizer.bos_token_id:
        source_ids = source_ids[1:]
    embeddings_to_average = embeddings[source_ids]
    new_embeddings[i] = embeddings_to_average.mean(dim=0)
    
    if (i + 1) % 10000 == 0:
        print(f"   Mapped {i + 1}/{target_tokenizer.vocab_size} embeddings", flush=True)
# Out:
#    Mapped 10000/131072 embeddings
#    Mapped 20000/131072 embeddings
#    Mapped 30000/131072 embeddings
#    Mapped 40000/131072 embeddings
#    Mapped 50000/131072 embeddings
#    Mapped 60000/131072 embeddings
#    Mapped 70000/131072 embeddings
#    Mapped 80000/131072 embeddings
#    Mapped 90000/131072 embeddings
#    Mapped 100000/131072 embeddings
#    Mapped 110000/131072 embeddings
#    Mapped 120000/131072 embeddings
#    Mapped 130000/131072 embeddings

# %%
model.resize_token_embeddings(embeddings.shape[1])
model.model.embed_tokens.weight = torch.nn.Parameter(new_embeddings)
print(f"Completed embedding transfer with {len(errors)} errors.")

model = model.to(torch.bfloat16)

model.save_pretrained("magibu-200m-base")
target_tokenizer.save_pretrained("magibu-200m-base")
# Out:
# Completed embedding transfer with 0 errors.
# ('magibu-200m-base/tokenizer_config.json',
#  'magibu-200m-base/chat_template.jinja',
#  'magibu-200m-base/tokenizer.json')

# %%
model.push_to_hub("alibayram/magibu-200m-base")
target_tokenizer.push_to_hub("alibayram/magibu-200m-base")
# Out:
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# README.md: 0.00B [00:00, ?B/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# CommitInfo(commit_url='https://huggingface.co/alibayram/magibu-200m-base/commit/2263e9729ccc5bc3410b866116709161e79ca4d9', commit_message='Upload tokenizer', commit_description='', oid='2263e9729ccc5bc3410b866116709161e79ca4d9', pr_url=None, repo_url=RepoUrl('https://huggingface.co/alibayram/magibu-200m-base', endpoint='https://huggingface.co', repo_type='model', repo_id='alibayram/magibu-200m-base'), pr_revision=None, pr_num=None)

# %%
parameter_count = sum(p.numel() for p in model.parameters())
print(f"Model parameter count: {parameter_count / 1_000_000:.2f}M")
# Out:
# Model parameter count: 202.79M
